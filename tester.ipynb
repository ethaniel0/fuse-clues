# %%
from config_parser import parse_config_file

# %%
conf = parse_config_file('devzero.yaml')

# %%
# fake a read
conf.evaluate_hook('read', **{'path': 'emptyfile', 'size': 1024, 'offset': 0})
# Out:
# Evaluating rule with condition: AlwaysCondition() and actions: [ReadWriteContentEvalAction(eval_str='chr(0) * size')]
# Condition met, executing actions...
# Executing action: ReadWriteContentEvalAction(eval_str='chr(0) * size')
# ...
